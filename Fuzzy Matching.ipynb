# %% [markdown]
# ### Screening Model
# #### Ronel Khan

# %% [markdown]
# First step is to import all the required libraries.
# We will need FuzzyWuzzy to essentially run our fuzzylogic match algorithm(s).
# Pandas is required in order to read the input and reference data as dataframes

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from IPython.display import Markdown, display
import pandas as pd

# %% [markdown]
# We will then need to load our list of Client names. Although the file is stored as a .txt file, we can use Pandas to read the file as a dataframe. Our Customer names will serve as our input data.

# %%
clients = pd.read_csv(r'C:\\Users\\ronel\\OneDrive\\Documents\\Python\\Client_List.csv')
display(clients)
# Out:
#                Client Name
# 0               JOHN BROWN
# 1              MIKA ARSHAD
# 2     ENRIQUE TORRES GOMEZ
# 3                HUD SALEM
# 4             AMBER DAVIES
# ...                    ...
# 5768          GAYNOR SMITH
# 5769      PEPILLO THOMPSON
# 5770          JARIYAH LONE
# 5771        WASFIYAH MAHDI
# 5772          EVONNE JONES
#
# [5773 rows x 1 columns]

# %% [markdown]
# We then load our dataset containing names of individuals and entities on the United States Office of Foreign Assets Control's (OFAC) list of Specially Designated Nationals List, or more commonly known as the SDN List. The SDN List will serve as our reference data.
#
# The steps taken to derive and cleanse the SDN dataset so that it contains all primary/legal names and aliases can be found on 'Data Cleanse.ipynb'

# %%
sdn = pd.read_csv('SDN.csv')
sdn['SDN_Names'] = sdn['SDN_Names'].str.upper()
display(sdn)
# Out:
#                                               SDN_Names
# 0              AEROCARIBBEAN AIRLINES; AERO-CARIBBEAN;
# 1              ANGLO-CARIBBEAN CO., LTD.; AVIA IMPORT;
# 2     BANCO NACIONAL DE CUBA; NATIONAL BANK OF CUBA;...
# 3                                   BOUTIQUE LA MAISON
# 4                                         CASA DE CUBA
# ...                                                 ...
# 8435  IBRAHIM, NASREEN HUSSEIN; IBRAHIM, NSRIN; IBRA...
# 8436      IBRAHIM, RANA HUSSEIN; IBRAHIM, RANA HUSSIN;
# 8437  JEDID, MILAD; JADID, MILAD; JADEED, MILAD; JED...
# 8438                        SYRIAN MINISTRY OF TOURISM
# 8439  RODRIGUEZ LOPEZ-CALLEJA, LUIS ALBERTO; RODRIGU...
#
# [8440 rows x 1 columns]

# %% [markdown]
# In order to effectively run our FuzzyWuzzy algorithm, we need the reference data as a list, and therefore are required to convert our dataframe to a list

# %%
sdnlist = sdn.values.tolist()
sdnlist
# Out:
# [['AEROCARIBBEAN AIRLINES; AERO-CARIBBEAN; '],
#  ['ANGLO-CARIBBEAN CO., LTD.; AVIA IMPORT; '],
#  ['BANCO NACIONAL DE CUBA; NATIONAL BANK OF CUBA;  BNC.'],
#  ['BOUTIQUE LA MAISON '],
#  ['CASA DE CUBA '],
#  ['CECOEX, S.A. '],
#  ['CIMEX '],
#  ['CIMEX IBERICA '],
#  ['CIMEX, S.A. '],
#  ['COMERCIAL IBEROAMERICANA, S.A.; COIBA; '],
#  ['COMERCIAL CIMEX, S.A. '],
#  ['COMERCIAL DE RODAJES Y MAQUINARIA, S.A.; CRYMSA; '],
#  ['COMERCIALIZACION DE PRODUCTOS VARIOS; COPROVA; COPROVA SARL; '],
#  ['COMPANIA DE IMPORTACION Y EXPORTACION IBERIA; CIMEX; '],
#  ['CORPORACION CIMEX, S.A. '],
#  ['COTEI '],
#  ['CRUZ, JUAN M. DE LA '],
#  ['CRYMSA - ARGENTINA, S.A. '],
#  ['CUBACANCUN CIGARS AND GIFT SHOPS '],
#  ['CUBAEXPORT '],
#  ['CUBAFRUTAS '],
#  ['CUBAN CIGARS TRADE '],
#  ['CUBANATUR '],
#  ['CUBATABACO '],
#  ['CUMEXINT, S.A. '],
#  ['DELVEST HOLDING, S.A.; DELVEST HOLDING COMPANY; '],
#  ['EDICIONES CUBANAS '],
#  ['EDYJU, S.A. '],
#  ['EMPRESA CUBANA DE AVIACION; CUBANA AIRLINES; '],
#  ['EMPRESA CUBANA DE PESCADOS Y MARISCOS; CARIBBEAN EXPORT ENTERPRISE;  CARIBEX.'],
#  ['EMPRESA DE TURISMO NACIONAL Y INTERNACIONAL; CUBATUR; '],
#  ['ETCO INTERNATIONAL COMMODITIES LTD. '],
#  ['ETCO INTERNATIONAL COMPANY, LIMITED '],
#  ['GALAX TRADING CO., LTD.; GALAX INC.; '],
#  ['GUTIERREZ REYES, JOSE '],
#  ['HAVIN BANK LIMITED; HAVANA INTERNATIONAL BANK, LTD; '],
#  ['HAVANATUR '],
#  ['INSTITUTO NACIONAL DE TURISMO DE CUBA '],
#  ['INTERCONSULT '],
#  ['KAVE, S.A. '],
#  ['LA EMPRESA CUBANA DE FLETES; CUFLET; CUBAN FREIGHT ENTERPRISE; '],
#  ['LEVERAGE, S.A. '],
#  ['NIREF '],
#  ['NORDSTRAND LTD. '],
#  ['NORDSTRAND MARITIME AND TRADING COMPANY '],
#  ['NORIEGA, MANUEL ANTONIO '],
#  ['PANAMERICAN IMPORT AND EXPORT COMMERCIAL CORPORATION '],
#  ['PESCABRAVA, S.A. '],
#  ['PRELASA '],
#  ['PRENSA LATINA CANADA LTD. '],
#  ['PRENSA LATINA '],
#  ['SERVINAVES, S.A. '],
#  ['SIEIRO DE NORIEGA, FELICIDAD '],
#  ['TROBER, S.A.; TROVER, S.A.; '],
#  ['TROPIC TOURS GMBH; TROPICANA TOURS GMBH; '],
#  ['VIAJES GUAMA, S.A. '],
#  ['VINALES TOURS '],
#  ['ABBAS, ABU; ZAYDAN, MUHAMMAD; '],
#  ['AL RAHMAN, SHAYKH UMAR ABD '],
#  ['AL ZAWAHIRI, DR. AYMAN; AL-ZAWAHIRI, AYMAN; SALIM, AHMAD FUAD; AL-ZAWAHIRI, AIMAN MUHAMMAD RABI; '],
#  ['AL-ZUMAR, ABBUD; ZUMAR, COLONEL ABBUD; '],
#  ['AWDA, ABD AL AZIZ '],
#  ['FADLALLAH, SHAYKH MUHAMMAD HUSAYN '],
#  ['HABBASH, GEORGE; HABASH, GEORGE; '],
#  ['HAWATMA, NAYIF; HAWATMEH, NAYIF; HAWATMAH, NAYIF; KHALID, ABU; '],
#  ['ISLAMBOULI, MOHAMMAD SHAWQI '],
#  ['JABRIL, AHMAD; JIBRIL, AHMAD; '],
#  ['NAJI, TALAL MUHAMMAD RASHID '],
#  ['NASRALLAH, HASAN; NASRALLAH, HASAN ABD-AL-KARIM; '],
#  ['TUFAYLI, SUBHI '],
#  ['YASSIN, SHEIK AHMED ISMAIL '],
#  ['MIDCO FINANCE S.A.; MIDCO FINANCIAL S.A.; MONTANA MANAGEMENT INC.; '],
#  ['COBALT REFINERY CO. INC. '],
#  ['LA COMPANIA GENERAL DE NIQUEL; GENERAL NICKEL SA; '],
#  ['INTERNATIONAL COBALT CO. INC. '],
#  ['MOA NICKEL SA '],
#  ["ABU MARZOOK, MOUSA MOHAMMED; MARZUK, MUSA ABU; ABU-MARZUQ, DR. MUSA; MARZOOK, MOUSA MOHAMED ABOU; ABU-MARZUQ, SA'ID; MARZOUK, MUSA ABU;  ABU-UMAR."],
#  ['HERRERA BUITRAGO, HELMER  PACHO; H7.'],
#  ['RODRIGUEZ OREJUELA, GILBERTO JOSE  THE CHESS PLAYER; LUCAS.'],
#  ['RODRIGUEZ OREJUELA, MIGUEL ANGEL  EL SENOR; PATRICIA; PATRICIO; PATTY; PAT; MANUEL; MANOLO; MIKE; MAURO; DOCTOR M.R.O..'],
#  ['SANTACRUZ LONDONO, JOSE  CHEPE; DON CHEPE; EL GORDO CHEPE.'],
#  ['CAVIEDES CRUZ, LEONARDO '],
#  ['HERMANN '],
#  ['MAR AZUL '],
#  ['SAND SWAN '],
#  ['TIFON '],
#  ['ABDALLAH, RAMADAN; ABDULLAH, DR. RAMADAN; SHALLAH, DR. RAMADAN ABDULLAH; SHALLAH, RAMADAN ABDALLA MOHAMED; '],
#  ['AGROPECUARIA BETANIA LTDA. '],
#  ['AGROPECUARIA Y REFORESTADORA HERREBE LTDA. '],
#  ['AMEZQUITA MENESES, SALUSTIO '],
#  ['ANGULO OROBIO (SEGUNDO), JOSE FRANCISCO '],
#  ['ARBOLEDA ROMERO, JULIO CESAR '],
#  ['BUITRAGO DE HERRERA, LUZ MERY '],
#  ['BUITRAGO MARIN, ADIELA '],
#  ['BUITRAGO MARIN, NUBIA '],
#  ['CONCRETOS CALI S.A. '],
#  ['CONSTRUCTORA DIMISA LTDA. '],
#  ['ABRIL CORTEZ, OLIVERIO; CORTEZ, OLIVERIO ABRIL; ABRIL CORTES, OLIVERIO; '],
#  ['CUARTES MORALES, JUAN CARLOS '],
#  ['ESCOBAR BUITRAGO, WALTER '],
#  ['GALINDO, GILMER ANTONIO; GUZMAN TRUJILLO, CARLOS ARTURO; '],
#  ['GALINDO HERRERA, DIANA PAOLA '],
#  ['GALINDO HERRERA, DIEGO ALEXANDER '],
#  ['GIRALDO SARRIA, OCTAVIO '],
#  ['GOMEZ BERRIO, OLMES DE JESUS; GOMEZ BERRIO, HOLMES DE JESUS; '],
#  ['HERNANDEZ CANOBAS, HECTOR FABIO '],
#  ['HERRERA BUITRAGO, ALVARO '],
#  ['HERRERA BUITRAGO, STELLA '],
#  ['IBANEZ LOPEZ, RAUL ALBERTO '],
#  ['CRIADERO DE POLLOS EL ROSAL S.A.; INDUSTRIA AVICOLA PALMASECA S.A.; '],
#  ['ADMINISTRACION INMOBILIARIA BOLIVAR S.A. '],
#  ['INMOBILIARIA U.M.V. S.A. '],
#  ['INVERSIONES EL PENON S.A. '],
#  ['INVERSIONES HERREBE LTDA. '],
#  ['INVERSIONES Y CONSTRUCCIONES VALLE S.A.; INCOVALLE; '],
#  ['LARRANAGA CALVACHE, JUAN CARLOS '],
#  ['LIBREROS DIEZ, ORLANDO '],
#  ['LINDO HURTADO, EDGAR '],
#  ['LINARES REYES, RICARDO JOSE; LLENARES REYES, JOSE RICARDO; '],
#  ['LOPERA LONDONO, VICENTE DE JESUS '],
#  ['MONROY ARCILA, FRANCISCO JOSE '],
#  ['MOSQUERA, JUAN CARLOS '],
#  ['MUNOZ PAZ, ADRIANA DEL SOCORRO '],
#  ['MUNOZ PAZ, JOAQUIN EMILIO '],
#  ['QUINTERO SALAZAR, LISIMACO '],
#  ['RAMIREZ CORTES, DELIA NHORA; RAMIREZ CORTES, DELIA NORA; '],
#  ['RAMIREZ VALENCIANO, WILLIAM '],
#  ['RIZO MORENO, JORGE LUIS '],
#  ['SAAVEDRA RESTREPO, JESUS MARIA '],
#  ['SALCEDO RAMIREZ, NHORA CLEMENCIA '],
#  ['SOCIEDAD CONSTRUCTORA Y ADMINISTRADORA DEL VALLE LTDA.; SOCOVALLE LTDA.; '],
#  ['URIBE GONZALEZ, JOSE ABELARDO '],
#  ['VALENCIA ARIAS, JHON GAVY; VALENCIA ARIAS, JOHN GABY; '],
#  ['VALENCIA ARIAS, LUIS FERNANDO '],
#  ['VALENCIA, REYNEL; VALENCIA, REINEL; '],
#  ['VALLE COMUNICACIONES LTDA.; VALLECOM; '],
#  ['VIAJES MERCURIO LTDA. '],
#  ['VILLEGAS ARIAS, MARIA DEISY; VILLEGAS ARIAS, MARIA DEICY; '],
#  ['AGROPECUARIA LA ROBLEDA S.A. '],
#  ['COMERCIAL DE NEGOCIOS CLARIDAD Y CIA. '],
#  ['COMERCIALIZADORA EXPERTA Y CIA. S. EN C. '],
#  ['CONSTRUCTORA ALTOS DEL RETIRO LTDA. '],
#  ['CONSTRUVIDA S.A. '],
#  ['CONSULTORIA EMPRESARIAL ESPECIALIZADA LTDA. '],
#  ['GANADERIAS DEL VALLE S.A. '],
#  ['IMPORTADORA Y COMERCIALIZADORA LTDA.; IMCOMER; '],
#  ['INDUSTRIA MADERERA ARCA LTDA. '],
#  ['INMOBILIARIA BOLIVAR LTDA. '],
#  ['INMOBILIARIA GALES LTDA. '],
#  ['INVERSIONES AGRICOLAS AVICOLAS Y GANADERAS LA CARMELITA LTDA. '],
#  ['INVERSIONES ARIO LTDA. '],
#  ['INVERSIONES CULZAT GUEVARA Y CIA. S.C.S. '],
#  ['INVERSIONES VILLA PAZ S.A. '],
#  ['MERCAVICOLA LTDA. '],
#  ['PROHUEVO DE COLOMBIA LTDA. '],
#  ['PROCESADORA DE POLLOS SUPERIOR S.A.; COMERCIALIZADORA INTERNACIONAL VALLE DE ORO S.A.; '],
#  ['VALLE DE ORO S.A. '],
#  ['ACERO PIEDRAHITA, CESAR AUGUSTO '],
#  ['ARIZABALETA ARZAYUS, PHANOR; ARIZABALETA ARZAYUS, FANOR; '],
#  ['BANDERAS, ARACELLY '],
#  ['BECERRA BECERRA, ALVARO '],
#  ['CASTRILLON CRUZ, MARIA LEONOR '],
#  ['CHAVARRO, HECTOR FABIO '],
#  ['CORREA PULGARIN, ERNESTO '],
#  ['CUERO MARTINEZ, OTALVARO '],
#  ['CULZAT LUGSIR, RAFAEL ALBERTO '],
#  ['DIAZ, MANUEL '],
#  ['DIAZ, ROSA ISABEL '],
#  ['FIGUEROA DE BRUSATIN, DACIER '],
#  ['GARCIA ROMERO, AUDRA YAMILE '],
#  ['GARCIA, FREDDY; GARCIA, FREDY; '],
#  ['HENAO HINESTROZA, MARIA NOHELIO '],
#  ['HERRERA BUITRAGO, WILLIAM '],
#  ['LONDONO DE UPEGUI, MARIA DEL CARMEN '],
#  ['LOPEZ RODRIGUEZ, CECILIA '],
#  ['LOPEZ ZAPATA, HERNAN DE JESUS '],
#  ['MORENO, CARLOS ARTURO '],
#  ['MURILLO MURILLO, JOSE TOLENTINO '],
#  ['PATINO RINCON, OCTAVIO '],
#  ['PEREZ ORTEGA, PUBLIO ELIECER '],
#  ['PEREZ SERNA, WILMAR ARMANDO '],
#  ['PIEDRAHITA GIRALDO, GUSTAVO ADOLFO '],
#  ['POSSO DE LONDONO, MARIA DEL CARMEN '],
#  ['RAMIREZ BUITRAGO, PLACIDO '],
#  ['RAMOS RAYO, HERIBERTO '],
#  ['REYES MURCIA, EDGAR '],
#  ['ROZO CLAVIJO, MIGUEL ANTONIO '],
#  ['SEPULVEDA SEPULVEDA, MANUEL SALVADOR '],
#  ['SERNA, MARIA NORBY; SERNA DE PEREZ, MARIA NORBI; '],
#  ['VALENCIA DE JARAMILLO, MARIA DIOCELINA '],
#  ['VALENCIA FRANCO, MANUEL '],
#  ['VARGAS LOPEZ, GUSTAVO ADOLFO '],
#  ['ZAMBRANO CERON, MARIA CONCEPCION '],
#  ['ZAMORA, JOSE HERNAN '],
#  ['MAFLA, CARLOS OBEYMAR; MAFLA, CARLOS OBEIMAR; OBEYMAR MAFLA, CARLOS; '],
#  ['MANAURE S.A.; AGROPECUARIA LA ROBLEDA S.A.; '],
#  ['VALLADARES LTDA.; AGROPECUARIA BETANIA LTDA.; '],
#  ['VALDIVIESO FONTAL, DIEGO '],
#  ['BANK MARKAZI JOMHOURI ISLAMI IRAN; CENTRAL BANK OF THE ISLAMIC REPUBLIC OF IRAN; BANK MARKAZI IRAN; CENTRAL BANK OF IRAN; '],
#  ['BANK MASKAN; HOUSING BANK (OF IRAN); '],
#  ["BANK REFAH KARGARAN; WORKERS' WELFARE BANK (OF IRAN); BANK REFAH; "],
#  ["AL QA'IDA; ISLAMIC SALVATION FOUNDATION; THE GROUP FOR THE PRESERVATION OF THE HOLY SITES; THE ISLAMIC ARMY FOR THE LIBERATION OF THE HOLY PLACES; THE WORLD ISLAMIC FRONT FOR JIHAD AGAINST JEWS AND CRUSADERS; AL QAEDA; THE BASE; USAMA BIN LADEN NETWORK; USAMA BIN LADEN ORGANIZATION; AL QAIDA; INTERNATIONAL FRONT FOR FIGHTING JEWS AND CRUSADES; ISLAMIC ARMY FOR THE LIBERATION OF HOLY SITES; AL-JIHAD; EGYPTIAN AL-JIHAD; EGYPTIAN ISLAMIC JIHAD; NEW JIHAD; THE JIHAD GROUP; "],
#  ['AL-MASRI, ABU HAFS; ABDULLAH, SHEIKH TAYSIR; ATEF, MUHAMMAD; EL KHABIR, ABU HAFS EL MASRY; ATIF, MUHAMMAD; ABU SITTA, SUBHI; ATIF, MOHAMED;  TAYSIR; ABU HAFS.'],
#  ["MUSA, RIFA'I AHMAD TAHA; ABD-AL-WAHAB, ABD-AL-HAI AHMAD; 'ABD ALLAH, 'ISSAM 'ALI MUHAMMAD; AL-KAMEL, SALAH 'ALI; TAHA MUSA, RIFA'I AHMAD; THABIT 'IZ;  ABD-AL-IZ; ABU YASIR."],
#  ['ALKALA ASOCIADOS S.A.; INVHERESA S.A.; '],
#  ['C.N.A. PUBLICIDAD LTDA. '],
#  ['CAMPO VERDE LTDA. '],
#  ['COLOMBIANA DE CERDOS LTDA.; COLCERDOS LTDA.; '],
#  ['COMPANIA ADMINISTRADORA DE VIVIENDA S.A.; INVERSIONES GEMINIS S.A.; '],
#  ['CONSTRUCTORA EL NOGAL S.A.; CONSTRUEXITO S.A.; CONE S.A.; '],
#  ["DISTRIBUIDORA DE ELEMENTOS PARA LA CONSTRUCCION S.A.; D'ELCON S.A.; "],
#  ['INVERSIONES EL GRAN CRISOL LTDA.; W. HERRERA Y CIA. S. EN C.; '],
#  ['INVERSIONES NAMOS Y CIA. LTDA. '],
#  ['K. P. TO JEANS WEAR S. DE H. '],
#  ['MATADERO METROPOLITANO LTDA. '],
#  ['SAN MATEO S.A.; INVERSIONES BETANIA LTDA.; INVERSIONES BETANIA S.A.; '],
#  ['TITOS BOLO CLUB '],
#  ["VILLA DE ARTE S. DE H.; VILLA D'ARTE; "],
#  ['OMAR, MOHAMMED '],
#  ["TALIBAN; ISLAMIC MOVEMENT OF TALIBAN; TAHRIKE ISLAMI'A TALIBAN; TALEBAN; TALIBAN ISLAMIC MOVEMENT; TALIBANO ISLAMI TAHRIK; "],
#  ['URDINOLA GRAJALES, IVAN; URDINOLA GRAJALES, JAIRO IVAN; '],
#  ['URDINOLA GRAJALES, JULIO FABIO '],
#  ['AGROINVERSORA URDINOLA HENAO Y CIA. S.C.S. '],
#  ['COMERCIALIZADORA DE CARNES LTDA.; COMECARNES LTDA.; '],
#  ['CONSTRUCTORA E INMOBILIARIA URVALLE CIA. LTDA. '],
#  ['CONSTRUCTORA UNIVERSAL LTDA. '],
#  ['EXPLOTACIONES AGRICOLAS Y GANADERAS LA LORENA S.C.S.; EXAGAN; '],
#  ['INDUSTRIAS AGROPECUARIAS DEL VALLE LTDA. '],
#  ['INVERSIONES EL EDEN S.C.S. '],
#  ['SERVIAUTOS UNO A 1A LIMITADA; DIAGNOSTICENTRO LA GARANTIA; '],
#  ['HENAO MONTOYA, LORENA '],
#  ['AMEZCUA CONTRERAS, JOSE DE JESUS; AMESCUA, CHUEY; AMEZCUA, CHUY; AMEZCUA CONTRERAS, JESUS; AMEZCUA, JOSE DE JESUS; HERNANDEZ, ADAN; '],
#  ['AMEZCUA CONTRERAS, LUIS IGNACIO; AMEZCUA, LUIS; CONTRERAS, LUIS C.; LOPEZ, LUIS; LOZANO, EDUARDO; OCHOA, SALVADOR; RODRIGUEZ LOPEZ, SERGIO; '],
#  ['ARELLANO FELIX, RAMON EDUARDO; COMACHO RODRIGUES, GILBERTO; TORRES MENDEZ, RAMON; '],
#  ['CARO QUINTERO, RAFAEL; CARO QUINTERO, RAPHAEL; '],
#  ['CARRILLO FUENTES, VICENTE; CARRILLO FUENTES, ANDRES; '],
#  ['CHANG, CHI FU; KHUN SA; CHAN, CHANGTRAKUL; CHANG, SHI-FU; CHANG, XIFU; CHANGTRAKUL, CHAN; '],
#  ['HEATH, NOEL TIMOTHY; ZAMBA, NOEL HEATH; ZAMBO, NOEL HEATH; '],
#  ['OGUNGBUYI, OLUWOLE A.; ADEMULERO, BABESTAN OLUWOLE; BABESTAN, WOLE A.; OGUNGBUYI, WALLY; OGUNGBUYI, WOLE A.; SHOFESO, OLATUDE I.; SHOFESO, OLATUNDE IREWOLE; '],
#  ['OGUNGBUYI, ABENI O.; BABESTAN, ABENI O.; SHOFESO, OLATUTU TEMITOPE; '],
#  ['WEI, HSUEH KANG; CHARNCHAI, CHIWINNITIPANYA; CHIVINNITIPANYA, PRASIT; CHIWINNITIPANYA, CHARNCHAI; PRASIT, CHIVINNITIPANYA; PRASIT, CHEEWINNITTIPANYA; WEI, SHAO-KANG; WEI, SIA-KANG; WEI, XUEKANG; CHEEWINNITTIPANYA, PRASIT; '],
#  ['ARELLANO FELIX, BENJAMIN ALBERTO '],
#  ['HENAO MONTOYA, ARCANGEL DE JESUS '],
#  ['RAMIREZ ABADIA, JUAN CARLOS '],
#  ['AGRICOLA GANADERA HENAO GONZALEZ Y CIA. S.C.S. '],
#  ['COMPANIA AGROINVERSORA HENAGRO LTDA. '],
#  ['DESARROLLOS COMERCIALES E INDUSTRIALES HENAO GONZALEZ Y CIA. S.C.S. '],
#  ['MAQUINARIA TECNICA Y TIERRAS LTDA.; M.T.T. LTDA.; '],
#  ['ORGANIZACION EMPRESARIAL A DE J HENAO M E HIJOS Y CIA. S.C.S. '],
#  ['GONZALEZ BENITEZ, OLGA PATRICIA '],
#  ['ISLAMIC MOVEMENT OF UZBEKISTAN  IMU.'],
#  ['CAVIEDES DILEO Y CIA. S.C.S. '],
#  ['HAPPY DAYS S. DE H. '],
#  ['VESTIMENTA J Y J S. DE H. '],
#  ['PATINO FOMEQUE, VICTOR JULIO; PATINO FOMEQUE, VICTOR HUGO; '],
#  ['INDUSTRIA DE PESCA SOBRE EL PACIFICO S.A; INPESCA S.A.; '],
#  ['AL-IRAQI, ABD AL-HADI; ABU ABDALLAH; AL-IRAQI, ABDAL AL-HADI; '],
#  ['SHIHATA, THIRWAT SALAH; ABDALLAH, TARWAT SALAH; THIRWAT, SHAHATA; THIRWAT, SALAH SHIHATA; '],
#  ['AHMAD, TARIQ ANWAR AL-SAYYID; FATHI, AMR AL-FATIH; FARAG, HAMDI AHMAD; '],
#  ['MAKHTAB AL-KHIDAMAT/AL KIFAH '],
#  ['WAFA HUMANITARIAN ORGANIZATION; AL WAFA; AL WAFA ORGANIZATION; WAFA AL-IGATHA AL-ISLAMIA; '],
#  ['AL RASHID TRUST; AL RASHEED TRUST; AL-RASHID TRUST; AL-RASHEED TRUST; AL AMIN WELFARE TRUST; AL AMIN TRUST; AL AMEEN TRUST; AL-AMEEN TRUST; AL MADINA TRUST; AL-MADINA TRUST; MAYMAR TRUST; MAIMAR TRUST; MOMAR TRUST; MEYMAR TRUST; '],
#  ['MAMOUN DARKAZANLI IMPORT-EXPORT COMPANY; DARKAZANLI COMPANY; DARKAZANLI EXPORT-IMPORT SONDERPOSTEN; '],
#  ['ABDULLAH, ABDULLAH AHMED; AL-MASRI, ABU MOHAMED;  ABU MARIAM; SALEH.'],
#  ['ALI, AHMED MOHAMMED HAMED; ABDUREHMAN, AHMED MOHAMMED; AHMED, AHMED; ALI, HAMED; ALI, AHMED MOHAMMED; AL-MASRI, AHMAD; AL-SURIR, ABU ISLAM; HEMED, AHMED; SHIEB, AHMED;  ABU FATIMA; ABU ISLAM; ABU KHADIIJAH; AHMED HAMED; AHMED THE EGYPTIAN; SHUAIB.'],
#  ['AL-MUGHASSIL, AHMAD IBRAHIM; AL-MUGHASSIL, AHMED IBRAHIM;  ABU OMRAN.'],
#  ['AL-NASSER, ABDELKARIM HUSSEIN MOHAMED '],
#  ['AL-YACOUB, IBRAHIM SALIH MOHAMMED '],
#  ['ATWA, ALI; BOUSLIM, AMMAR MANSOUR; SALIM, HASSAN ROSTOM; '],
#  ['EL-HOORIE, ALI SAED BIN ALI; AL-HOURI, ALI SAED BIN ALI; EL-HOURI, ALI SAED BIN ALI; '],
#  ['FADHIL, MUSTAFA MOHAMED; ELBISHY, MOUSTAFA ALI; MOHAMMED, MUSTAFA; FAZUL, MUSTAFA; FADIL, MUSTAFA MUHAMAD; AL MASRI, ABD AL WAKIL; ALI, HASSAN; MAN, NU; JIHAD, ABU; AL-NUBI, ABU;  HUSSEIN; ANIS, ABU; YUSSRR, ABU; KHALID.'],
#  ['GHAILANI, AHMED KHALFAN; GHILANI, AHMAD KHALAFAN; AHMED, AHMED KHALFAN; AHMED, ABUBAKAR K.; AHMED, ABUBAKARY K.; AHMAD, ABU BAKR; KHALFAN, AHMED; ALI, AHMED KHALFAN; AHMED, ABUBAKAR KHALFAN; GHAILANI, AHMED; AL TANZANI, AHMAD; GHAILANI, ABUBAKARY KHALFAN AHMED; HUSSEIN, MAHAFUDH ABUBAKAR AHMED ABDALLAH; MOHAMMED, SHARIFF OMAR;  AHMED, A.; KHABAR, ABU; BAKR, ABU; FOOPIE; FUPI; AHMED THE TANZANIAN.'],
#  ['ADP, S.C. '],
#  ['COMPLEJO TURISTICO OASIS, S.A. DE C.V.; OASIS BEACH RESORT & CONVENTION CENTER; OASIS BEACH RESORT AND CONVENTION CENTER; '],
#  ['DISTRIBUIDORA IMPERIAL DE BAJA CALIFORNIA, S.A. DE C.V.; DISTRIBUIDORA IMPERIAL; DIBC; '],
#  ['FARMACIA VIDA SUPREMA, S.A. DE C.V.; FARMACIAS VIDA; FARMACIA VIDA; '],
#  ['FORPRES, S.C. '],
#  ['GEX EXPLORE S. DE R.L. DE C.V. '],
#  ['OPERADORA VALPARK, S.A. DE C.V. '],
#  ['VALPARK, S.A. DE C.V. '],
#  ['AGUILAR AMAO, MIGUEL '],
#  ['AGUIRRE GALINDO, MANUEL '],
#  ['ARELLANO FELIX, ENEDINA; ARELLANO FELIX DE TOLEDO, ENEDINA; '],
#  ['FREGOSO AMEZQUITA, MARIA ANTONIETA '],
#  ['GIL GARCIA, JOSE ALEJANDRO '],
#  ['HERNANDEZ PULIDO, MARIA ELDA '],
#  ['MIJARES TRANCOSO, GILBERTO '],
#  ['MORENO MEDINA, LUIS IGNACIO '],
#  ['OROPEZA MEDRANO, FRANCISCO JAVIER '],
#  ['RAMIREZ AGUIRRE, SERGIO HUMBERTO '],
#  ['TOLEDO CARREJO, LUIS RAUL '],
#  ['ABAUNZA MARTINEZ, JAVIER '],
#  ['ALBERDI URANGA, ITZIAR '],
#  ['ALCALDE LINARES, ANGEL '],
#  ['ALBISU IRIARTE, MIGUEL '],
#  ['ARZALLUS TAPIA, EUSEBIO '],
#  ['ELCORO AYASTUY, PAULO '],
#  ['FIGAL ARRANZ, ANTONIO AGUSTIN '],
#  ['GOGEASCOECHEA ARRONATEGUI, ENEKO '],
#  ['GOIRICELAYA GONZALEZ, CRISTINA '],
#  ['IPARRAGUIRRE GUENECHEA, MARIA SOLEDAD '],
#  ['MORCILLO TORRES, GRACIA '],
#  ['MUGICA GONI, AINHOA '],
#  ['MUNOA ORDOZGOITI, ALONA '],
#  ['NARVAEZ GONI, JUAN JESUS '],
#  ['OLARRA GURIDI, JUAN ANTONIO '],
#  ['ORBE SEVILLANO, ZIGOR '],
#  ['OTEGUI UNANUE, MIKEL '],
#  ['PEREZ ARAMBURU, JON INAKI '],
#  ['SAEZ DE EGUILAZ MURGUIONDO, CARLOS '],
#  ['URANGA ARTOLA, KEMEN '],
#  ['VILA MICHELENA, FERMIN '],
#  ["AL-HARAMAIN ISLAMIC FOUNDATION; AL-HARAMAIN; AL-HARAMEIN; AL-HARAMAYN; ALHARAMAIN FOUNDATION; ALHARAMEIN FOUNDATION; ALHARAMAYN FOUNDATION; AL-HARAMEIN ISLAMIC FOUNDATION; AL-HARAMAYN ISLAMIC FOUNDATION; ALHARAMAIN ISLAMIC FOUNDATION; ALHARAMEIN ISLAMIC FOUNDATION; ALHARAMAYN ISLAMIC FOUNDATION; AL-HARAMAIN HUMANITARIAN FOUNDATION; AL-HARAMEIN HUMANITARIAN FOUNDATION; AL-HARAMAYN HUMANITARIAN FOUNDATION; MU'ASSASAT AL-HARAMAIN AL-KHAYRIYYA; MU'ASSASAT AL-HARAMEIN AL-KHAYRIYYA; MU'ASSASAT AL-HARAMAYN AL-KHAYRIYYA; ALHARAMAIN HUMANITARIAN FOUNDATION; ALHARAMEIN HUMANITARIAN FOUNDATION; ALHARAMAYN HUMANITARIAN FOUNDATION; AL-HARAMAIN FOUNDATION; AL-HARAMEIN FOUNDATION; AL-HARAMAYN FOUNDATION; VAZIR; VEZIR; "],
#  ['AL-AQSA MARTYRS BRIGADE; AL-AQSA MARTYRS BATTALION; '],
#  ['THE AID ORGANIZATION OF THE ULEMA; AL RASHID TRUST; AL RASHEED TRUST; AL-RASHEED TRUST; AL-RASHID TRUST; '],
#  ['AOUADI, MOHAMED BEN BELGACEM; AOUADI, MOHAMED BEN BELKACEM; '],
#  ["BEN HENI, LASED; BEN HANI, AL AS'AD; "],
#  ['BOUCHOUCHA, MOKHTAR; BUSHUSHA, MOKHTAR; BOUCHOUCHA, AL-MOKHTAR BEN MOHAMED BEN AL-MOKHTAR; '],
#  ['ES SAYED, ABDELKADER MAHMOUD; ES SAYED, KADER; '],
#  ['ESSID, SAMI BEN KHEMAIS; ELSSEID, SAMI BEN KHAMIS BEN SALEH; '],
#  ['AL-FAWAZ, KHALID ABD AL-RAHMAN HAMD; AL-FAUWAZ, KHALED; AL-FAUWAZ, KHALED A.; AL-FAWWAZ, KHALID; AL FAWWAZ, KHALID; AL FAWWAZ, KHALED; AL-FAWWAZ, KHALED; AL FAWAZ, KHALID ABDULRAHMAN H.; '],
#  ['AL-MASRI, ABU HAMZA; AL-MISRI, ABU HAMZA; MUSTAFA, MUSTAFA KAMEL; KAMEL, MUSTAFA; EMAN, ADAM RAMSEY; '],
#  ['APAOLAZA SANCHO, IVAN '],
#  ['BERASATEGUI ESCUDERO, ISMAEL '],
#  ['GALLASTEGUI SODUPE, LEXURI '],
#  ['PALACIOS ALDAY, GORKA '],
#  ['QUINTANA ZORROZUA, ASIER '],
#  ['RUBENACH ROIG, JUAN LUIS '],
#  ['ZUBIAGA BRAVO, MANEX '],
#  ['ASKATASUNA; GESTORAS PRO-AMNISTIA; '],
#  ['DA COSTA, LUIS FERNANDO; BEIRA-MAR, FERNANDINHO; '],
#  ['GONZALEZ QUIRARTE, EDUARDO; GONZALEZ QUIRARTE, LALO; GONZALEZ QUIRARTE, JOSE; GONZALEZ LOPEZ, GREGORIO; ORELLANA ERAZO, HECTOR MANUEL; GOMEZ CHAVEZ, GABRIEL; '],
#  ['IBRAHIM, HAJI; KHAN AFRIDI, HAJI IBRAHIM; KHAN, HAJI IBRAHIM; IBRAHIM, HAJI EHAI; '],
#  ['KNOWLES, SAMUEL; KNOWLES, JR., SAMUEL; '],
#  ['TUITO, ODED; TVITO, ODED; TUITO, DANIEL; TVITO, DANIEL; TUITO, DAVID; MAMO, ELIYAHU; REVIVO, SIMON; '],
#  ['VILLANUEVA MADRID, MARIO ERNESTO '],
#  ['ZAMBADA GARCIA, ISMAEL; ZAMBADA, EL MAYO; ZAMBADA GARCIA, ISMAEL MARIO; LOAIZA AVENDANO, JESUS; GARCIA HERNANDEZ, JAVIER; HIGUERA RENTERIA, ISMAEL; LOPEZ LANDEROS, JERONIMO; '],
#  ['BABBAR KHALSA INTERNATIONAL '],
#  ['INTERNATIONAL SIKH YOUTH FEDERATION  ISYF.'],
#  ["NEW PEOPLE'S ARMY / COMMUNIST PARTY OF THE PHILIPPINES; NPA; NEW PEOPLE'S ARMY; COMMUNIST PARTY OF THE PHILIPPINES;  CPP; NPP/CPP."],
#  ['SISON, JOSE MARIA; LIWINAG, ARMANDO; '],
#  ['BEN SOLTANE, ADEL; BEN SOLTANE, ADEL BEN AL-AZHAR BEN YOUSSEF; '],
#  ['BEN ATTIA, NABIL BEN MOHAMED BEN ALI '],
#  ['CHEKKOURI, YASSINE '],
#  ['JELASSI, RIADH BEN BELKASSEM BEN MOHAMED '],
#  ['KAMMOUN, MEHDI; KAMMOUN, MEHDI BEN MOHAMED BEN MOHAMED; '],
#  ['KISHK, SAMIR '],
#  ['MAAROUFI, TAREK BEN HABIB BEN AL-TOUMI '],
#  ['REMADNA, ABDELHALIM '],
#  ['THAER, MANSOUR '],
#  ['TLILI, AL-AZHAR BEN AMMAR BEN ABADALLAH '],
#  ['WADDANI, HABIB '],
#  ['EASTERN TURKISTAN ISLAMIC MOVEMENT; EASTERN TURKISTAN ISLAMIC PARTY; ETIM; ETIP; '],
#  ["JULAIDAN, WA'EL HAMZA ABD AL-FATAH; JALADIN, WA'EL HAMZA; JALADIN, WA'IL HAMZA; JALAIDAN, WA'EL HAMZA; JALAIDAN, WA'IL HAMZA; JULAIDAN, WA'IL HAMZA; JULAYDAN, WA'EL HAMZA; JULAYDAN, WA'IL HAMZA; JILDAN, WAIL H.A.;  ABU AL-HASAN AL MADANI."],
#  ['BAHAJI, SAID '],
#  ['BINALSHIBH, RAMZI MOHAMMED ABDULLAH; BIN AL SHIBH, RAMZI; BINALSHEIDAH, RAMZI MOHAMED ABDULLAH; OMAR, RAMZI MOHAMMED ABDELLAH; '],
#  ['EL MOTASSADEQ, MOUNIR '],
#  ['ESSABAR, ZAKARYA; ESSABAR, ZAKARIYA; '],
#  ["TUNISIAN COMBAT GROUP; GCT; GROUPE COMBATTANT TUNISIEN; JAMA'A COMBATTANTE TUNISIEN; TUNISIAN COMBATANT GROUP;  JCT."],
#  ['GLOBAL RELIEF FOUNDATION, INC. '],
#  ["GLOBAL RELIEF FOUNDATION, INC.; FONDATION SECOURS MONDIAL A.S.B.L.; FONDATION SECOURS MONDIAL-BELGIQUE A.S.B.L.; FONDATION SECOURS MONDIAL-KOSOVA; FONDATION SECOURS MONDIAL VZW; FONDATION SECOURS MONDIAL 'WORLD RELIEF'; STICHTING WERELDHULP-BELGIE, V.Z.W.; SECOURS MONDIAL DE FRANCE;  FSM."],
#  ["JEMAA ISLAMIYAH; JEMA'A ISLAMIYAH; JEMA'A ISLAMIYYA; JEMA'A ISLAMIYYAH; JEMA'AH ISLAMIYAH; JEMA'AH ISLAMIYYAH; JEMAA ISLAMIYA; JEMAA ISLAMIYYA; JEMAA ISLAMIYYAH; JEMAAH ISLAMIAH; JEMAAH ISLAMIYAH; JEMAAH ISLAMIYYAH;  JI."],
#  ['GOMEZ BUSTAMANTE, LUIS HERNANDO '],
#  ['MONTOYA SANCHEZ, DIEGO LEON '],
#  ['AGRICOLA DOIMA DEL NORTE DEL VALLE LTDA. '],
#  ['AGROPECUARIA MIRALINDO S.A. '],
#  ['ARIZONA S.A. '],
#  ['GANADERIA EL VERGEL LTDA. '],
#  ['GANADERIAS BILBAO LTDA. '],
#  ['INMOBILIARIA EL ESCORIAL LTDA. '],
#  ['INMOBILIARIA LINARES LTDA. '],
#  ['INMOBILIARIA PASADENA LTDA. '],
#  ['INVERSIONES LA QUINTA Y CIA. LTDA. '],
#  ['LADRILLERA LA CANDELARIA LTDA. '],
#  ['MONTOYA LUNA E HIJOS Y CIA. S.C.S. '],
#  ['ORGANIZACION LUIS HERNANDO GOMEZ BUSTAMANTE Y CIA S.C.S. '],
#  ['VISCAYA LTDA.; VIZCAYA LTDA.; '],
#  ['GOMEZ APONTE, LAURA VICTORIA '],
#  ['GOMEZ GOMEZ, VIVIANA '],
#  ['GOMEZ JARAMILLO, OLGA CECILIA '],
#  ['HURTADO ROMERO, JAIRO JOSE '],
#  ['MENDEZ SALAZAR, JOHN JAIRO '],
#  ['MONTOYA SANCHEZ, EUGENIO; CARVAJAL TAFURT, HECTOR FABIO; '],
#  ['MONTOYA SANCHEZ, JUAN CARLOS '],
#  ['RUIZ CASTANO, MARIA HELENA '],
#  ['ECHEBERRIA SIMARRO, LEIRE '],
#  ['ECHEGARAY ACHIRICA, ALFONSO '],
#  ['IZTUETA BARANDICA, ENRIQUE '],
#  ['VALLEJO FRANCO, INIGO '],
#  ["BENEVOLENCE INTERNATIONAL FOUNDATION; AL BIR AL DAWALIA; BIF-USA; MEZHDUNARODNYJ BLAGOTVORITEL'NYJ FOND;  BIF."],
#  ['BENEVOLENCE INTERNATIONAL FUND; BENEVOLENT INTERNATIONAL FUND; BIF-CANADA; '],
#  ['BOSANSKA IDEALNA FUTURA; BECF CHARITABLE EDUCATIONAL CENTER; BENEVOLENCE EDUCATIONAL CENTER; BIF-BOSNIA; BOSNIAN IDEAL FUTURE; '],
#  ['MOROCCAN ISLAMIC COMBATANT GROUP; GICM; GROUPE ISLAMIQUE COMBATTANT MAROCAIN; '],
#  ["LAJNAT AL DAAWA AL ISLAMIYYA; ISLAMIC CALL COMMITTEE; LAJNA ALDAWA ALISALMIAH; LAJNA ALDAWA ALISLAMIA; LAJNA ALDAWA ALISLAMIYA; LAJNAT AL D'AWA AL ISLAMIAK; LAJNAT AL DAAWA AL ISLAMIYA; LAJNAT AL DAWA; LAJNAT AL DAWA AL ISLAMIA; LAJNAT ALDAWA AL ISLAMIAH; LAJNAT ALDAWA ALISLAMIA; "],
#  ['SAYADI, NABIL ABDUL SALAM  ABOU ZEINAB.'],
#  ['MACHAYA, JAISON MAX KOKERAI '],
#  ['MADE, JOSEPH MTAKWESE '],
#  ['MADZONGWE, EDNA '],
#  ['MALINGA, JOSHUA '],
#  ['MANYONDA, KENNETH '],
#  ['MARUMAHOKO, RUEBEN '],
#  ['MASUKU, ANGELINE '],
#  ['MNANGAGWA, EMMERSON DAMBUDZO '],
#  ['MOHADI, KEMBO CAMPBELL DUGISHI '],
#  ['MOYO, JONATHAN NATHANIEL '],
#  ['MOYO, SIMON KHAYA '],
#  ['MPOFU, OBERT MOSES '],
#  ['MUCHENA, OLIVIA NYEMBEZI '],
#  ['MUCHINGURI, OPPAH CHAMU ZVIPANGE '],
#  ['MUGABE, GRACE '],
#  ['MUJURU, JOYCE TEURAI ROPA '],
#  ['MUMBENGEGWI, SAMUEL SIMBARASHE SIMBANENDUKU '],
#  ['MURERWA, HERBERT MUCHEMWA '],
#  ['MUSHOHWE, CHRISTOPHER CHINDOTI '],
#  ['MUTASA, DIDYMUS NOEL EDWIN '],
#  ['MUTIWEKUZIVA, KENNETH KEPARADZA '],
#  ['MUZENDA, TSITSI '],
#  ['MUZONZINI, ELISHA '],
#  ['NCUBE, ABEDINICO '],
#  ['NHEMA, CHENAYAIMOYO DUNSTAN FRANCIS '],
#  ['PARIRENYATWA, DAVID PAGWESE '],
#  ['POTE, SELINA '],
#  ['SEKERAMAYI, SIDNEY TIGERE '],
#  ['SHIRI, PERENCE '],
#  ['SIKOSANA, ABSOLOM '],
#  ['ZIMONDI, PARADZAI '],
#  ['VALENCIA TRUJILLO, JOAQUIN MARIO '],
#  ['VALENCIA TRUJILLO, GUILLERMO '],
#  ['BANANERA AGRICOLA S.A.; BANAGRICOLA S.A.; '],
#  ['BOLSAK E.U.; BOLSAK S.A.; '],
#  ['CIA. ANDINA DE EMPAQUES LTDA.; COEMPAQUES LTDA.; '],
#  ['CIA. MINERA DAPA S.A. '],
#  ['COMPANIA DE FOMENTO MERCANTIL S.A. '],
#  ['CONSTRUCCIONES PROGRESO DEL PUERTO S.A.; CONPUERTO S.A.; '],
#  ['CREDISA S.A.; COMERCIALIZADORA AUTOMOTRIZ S.A.; '],
#  ['CRIADERO LA LUISA E.U.; INDUSTRIA AGROPECUARIA SANTA ELENA LTDA.; '],
#  ['DRAGADOS Y MUELLES GAVIOTA LTDA. '],
#  ['GEOPLASTICOS S.A.; COLOMBIANA DE BOLSAS S.A.; '],
#  ['GESTORA MERCANTIL S.A. '],
#  ['GRANJA LA SIERRA LTDA. '],
#  ['GRAN MUELLE S.A. '],
#  ['MIRA E.U. '],
#  ['OCCIDENTAL DE PAPELES LTDA.; OCCIPAPEL LTDA.; '],
#  ['SERVICIO AEREO DE SANTANDER E.U.; S.A.S. E.U.; '],
#  ['TRINIDAD LTDA. Y CIA. S.C.S. '],
#  ['UNIDAS S.A. '],
#  ['UNIPAPEL S.A.; UNIPAPEL S.A. BOLSAS DE PAPEL PAPELES SOBRES; '],
#  ['VALOR LTDA. S.C.S. '],
#  ['MONTANO ALVAREZ, LUIS HERNANDO '],
#  ['TODOBOLSAS Y COLSOBRES; RODRIGUEZ CARRENO LTDA. TODO BOLSAS Y COLSOBRES; '],
#  ["AL-AQSA FOUNDATION; AL-AQSA SPANMAL STIFTELSE; AL-AQSA ASBL; AL-AQSA CHARITABLE FOUNDATION; AL-AQSA CHARITABLE ORGANIZATION; AL-AQSA E.V.; AL-AQSA INTERNATIONAL FOUNDATION; AL-AQSA ISLAMIC CHARITABLE SOCIETY; AL-AQSA SINABIL ESTABLISHMENT; AL-AQSA SPANM I STIFTELSE; AQSSA SOCIETY; AQSSA SOCIETY YEMEN; CHARITABLE AL-AQSA ESTABLISHMENT; CHARITABLE SOCIETY TO HELP THE NOBLE AL-AQSA; FORENINGEN AL-AQSA; ISLAMIC CHARITABLE SOCIETY FOR AL-AQSA; MU' ASA AL-AQSA AL-KHAYRIYYA; MU' ASSA SANABIL AL-AQSA AL-KHAYRIYYA; SANABIL AL-AQSA CHARITABLE FOUNDATION; STICHTING AL-AQSA; SWEDISH CHARITABLE AQSA EST.; NUSRAT AL-AQSA AL-SHARIF; "],
#  ["AL-AQSA E.V.; AL-AQSA SPANMAL STIFTELSE; AL-AQSA ASBL; AL-AQSA FOUNDATION; AL-AQSA CHARITABLE FOUNDATION; AL-AQSA CHARITABLE ORGANIZATION; AL-AQSA INTERNATIONAL FOUNDATION; AL-AQSA ISLAMIC CHARITABLE SOCIETY; AL-AQSA SINABIL ESTABLISHMENT; AL-AQSA SPANM I STIFTELSE; AQSSA SOCIETY; AQSSA SOCIETY YEMEN; CHARITABLE AL-AQSA ESTABLISHMENT; CHARITABLE SOCIETY TO HELP THE NOBLE AL-AQSA; FORENINGEN AL-AQSA; ISLAMIC CHARITABLE SOCIETY FOR AL-AQSA; MU' ASA AL-AQSA AL-KHAYRIYYA; MU' ASSA SANABIL AL-AQSA AL-KHAYRIYYA; SANABIL AL-AQSA CHARITABLE FOUNDATION; STICHTING AL-AQSA; SWEDISH CHARITABLE AQSA EST.; NUSRAT AL-AQSA AL-SHARIF; "],
#  ["STICHTING AL-AQSA; AL-AQSA SPANMAL STIFTELSE; AL-AQSA ASBL; AL-AQSA CHARITABLE FOUNDATION; AL-AQSA CHARITABLE ORGANIZATION; AL-AQSA E.V.; AL-AQSA FOUNDATION; AL-AQSA INTERNATIONAL FOUNDATION; AL-AQSA ISLAMIC CHARITABLE SOCIETY; AL-AQSA SINABIL ESTABLISHMENT; AL-AQSA SPANM I STIFTELSE; AQSSA SOCIETY; AQSSA SOCIETY YEMEN; CHARITABLE AL-AQSA ESTABLISHMENT; CHARITABLE SOCIETY TO HELP THE NOBLE AL-AQSA; FORENINGEN AL-AQSA; ISLAMIC CHARITABLE SOCIETY FOR AL-AQSA; MU' ASA AL-AQSA AL-KHAYRIYYA; MU' ASSA SANABIL AL-AQSA AL-KHAYRIYYA; SANABIL AL-AQSA CHARITABLE FOUNDATION; SWEDISH CHARITABLE AQSA EST.; NUSRAT AL-AQSA AL-SHARIF; "],
#  ["FORENINGEN AL-AQSA; AL-AQSA SPANMAL STIFTELSE; AL-AQSA ASBL; AL-AQSA CHARITABLE FOUNDATION; AL-AQSA CHARITABLE ORGANIZATION; AL-AQSA E.V.; AL-AQSA FOUNDATION; AL-AQSA INTERNATIONAL FOUNDATION; AL-AQSA ISLAMIC CHARITABLE SOCIETY; AL-AQSA SINABIL ESTABLISHMENT; AL-AQSA SPANM I STIFTELSE; AQSSA SOCIETY; AQSSA SOCIETY YEMEN; CHARITABLE AL-AQSA ESTABLISHMENT; CHARITABLE SOCIETY TO HELP THE NOBLE AL-AQSA; ISLAMIC CHARITABLE SOCIETY FOR AL-AQSA; MU' ASA AL-AQSA AL-KHAYRIYYA; MU' ASSA SANABIL AL-AQSA AL-KHAYRIYYA; SANABIL AL-AQSA CHARITABLE FOUNDATION; STICHTING AL-AQSA; SWEDISH CHARITABLE AQSA EST.; NUSRAT AL-AQSA AL-SHARIF; "],
#  ["AL-AQSA; AL-AQSA SPANMAL STIFTELSE; AL-AQSA CHARITABLE FOUNDATION; AL-AQSA CHARITABLE ORGANIZATION; AL-AQSA E.V.; AL-AQSA FOUNDATION; AL-AQSA INTERNATIONAL FOUNDATION; AL-AQSA ISLAMIC CHARITABLE SOCIETY; AL-AQSA SINABIL ESTABLISHMENT; AL-AQSA SPANM I STIFTELSE; AQSSA SOCIETY; AQSSA SOCIETY YEMEN; CHARITABLE AL-AQSA ESTABLISHMENT; CHARITABLE SOCIETY TO HELP THE NOBLE AL-AQSA; FORENINGEN AL-AQSA; ISLAMIC CHARITABLE SOCIETY FOR AL-AQSA; MU' ASA AL-AQSA AL-KHAYRIYYA; MU' ASSA SANABIL AL-AQSA AL-KHAYRIYYA; SANABIL AL-AQSA CHARITABLE FOUNDATION; STICHTING AL-AQSA; SWEDISH CHARITABLE AQSA EST.; NUSRAT AL-AQSA AL-SHARIF;  ASBL."],
#  ["AQSSA SOCIETY YEMEN; AL-AQSA SPANMAL STIFTELSE; AL-AQSA ASBL; AL-AQSA CHARITABLE FOUNDATION; AL-AQSA CHARITABLE ORGANIZATION; AL-AQSA E.V.; AL-AQSA FOUNDATION; AL-AQSA INTERNATIONAL FOUNDATION; AL-AQSA ISLAMIC CHARITABLE SOCIETY; AL-AQSA SINABIL ESTABLISHMENT; AL-AQSA SPANM I STIFTELSE; AQSSA SOCIETY; CHARITABLE AL-AQSA ESTABLISHMENT; CHARITABLE SOCIETY TO HELP THE NOBLE AL-AQSA; FORENINGEN AL-AQSA; ISLAMIC CHARITABLE SOCIETY FOR AL-AQSA; MU' ASA AL-AQSA AL-KHAYRIYYA; MU' ASSA SANABIL AL-AQSA AL-KHAYRIYYA; SANABIL AL-AQSA CHARITABLE FOUNDATION; STICHTING AL-AQSA; SWEDISH CHARITABLE AQSA EST.; NUSRAT AL-AQSA AL-SHARIF; "],
#  ["AL-AQSA FOUNDATION; AL-AQSA SPANMAL STIFTELSE; AL-AQSA ASBL; AL-AQSA CHARITABLE FOUNDATION; AL-AQSA CHARITABLE ORGANIZATION; AL-AQSA E.V.; AL-AQSA INTERNATIONAL FOUNDATION; AL-AQSA ISLAMIC CHARITABLE SOCIETY; AL-AQSA SINABIL ESTABLISHMENT; AL-AQSA SPANM I STIFTELSE; AQSSA SOCIETY; AQSSA SOCIETY YEMEN; CHARITABLE AL-AQSA ESTABLISHMENT; CHARITABLE SOCIETY TO HELP THE NOBLE AL-AQSA; FORENINGEN AL-AQSA; ISLAMIC CHARITABLE SOCIETY FOR AL-AQSA; MU' ASA AL-AQSA AL-KHAYRIYYA; MU' ASSA SANABIL AL-AQSA AL-KHAYRIYYA; SANABIL AL-AQSA CHARITABLE FOUNDATION; STICHTING AL-AQSA; SWEDISH CHARITABLE AQSA EST.; NUSRAT AL-AQSA AL-SHARIF; "],
#  ["AL-AQSA FOUNDATION; AL-AQSA SPANMAL STIFTELSE; AL-AQSA ASBL; AL-AQSA CHARITABLE FOUNDATION; AL-AQSA CHARITABLE ORGANIZATION; AL-AQSA E.V.; AL-AQSA INTERNATIONAL FOUNDATION; AL-AQSA ISLAMIC CHARITABLE SOCIETY; AL-AQSA SINABIL ESTABLISHMENT; AL-AQSA SPANM I STIFTELSE; AQSSA SOCIETY; AQSSA SOCIETY YEMEN; CHARITABLE AL-AQSA ESTABLISHMENT; CHARITABLE SOCIETY TO HELP THE NOBLE AL-AQSA; FORENINGEN AL-AQSA; ISLAMIC CHARITABLE SOCIETY FOR AL-AQSA; MU' ASA AL-AQSA AL-KHAYRIYYA; MU' ASSA SANABIL AL-AQSA AL-KHAYRIYYA; SANABIL AL-AQSA CHARITABLE FOUNDATION; STICHTING AL-AQSA; SWEDISH CHARITABLE AQSA EST.; NUSRAT AL-AQSA AL-SHARIF; "],
#  ["AL-AQSA FOUNDATION; AL-AQSA SPANMAL STIFTELSE; AL-AQSA ASBL; AL-AQSA CHARITABLE FOUNDATION; AL-AQSA CHARITABLE ORGANIZATION; AL-AQSA E.V.; AL-AQSA INTERNATIONAL FOUNDATION; AL-AQSA ISLAMIC CHARITABLE SOCIETY; AL-AQSA SINABIL ESTABLISHMENT; AL-AQSA SPANM I STIFTELSE; AQSSA SOCIETY; AQSSA SOCIETY YEMEN; CHARITABLE AL-AQSA ESTABLISHMENT; CHARITABLE SOCIETY TO HELP THE NOBLE AL-AQSA; FORENINGEN AL-AQSA; ISLAMIC CHARITABLE SOCIETY FOR AL-AQSA; MU' ASA AL-AQSA AL-KHAYRIYYA; MU' ASSA SANABIL AL-AQSA AL-KHAYRIYYA; SANABIL AL-AQSA CHARITABLE FOUNDATION; STICHTING AL-AQSA; SWEDISH CHARITABLE AQSA EST.; NUSRAT AL-AQSA AL-SHARIF; "],
#  ['ADEMI, XHEVAT '],
#  ['ADILI, GAFUR '],
#  ['ALBANIAN NATIONAL ARMY; AKSH;  ANA.'],
#  ['ALISPAHIC, BAKIR '],
#  ['ARMY OF THE REPUBLIC OF ILIRIDA  ARI.'],
#  ['ARSENOVIC, DJOJO '],
#  ['BAJAGIC, ZVONKO  DUGA PUSKA.'],
#  ['BALA, HARADIN '],
#  ['BANOVIC, PREDRAG '],
#  ['BEQIRI, IDAJET; BEQIRI, HIDAJET; '],
#  ['BEXHETI, NURI '],
#  ['BIO CORPORATION; BOSNIAN INVESTMENT ORGANIZATION; '],
#  ['BJELICA, MILOVAN  CICKO.'],
#  ['BLAGOJEVIC, VIDOJE '],
#  ['BLASKIC, TIHOMIR '],
#  ['BORAVCANIN, LJUBOMIR '],
#  ['BOROVNICA, GORAN '],
#  ['BOSKOVSKI, LJUBE '],
#  ['BRDJANIN, RADOSLAV '],
#  ['BUTKA, SPIRO '],
#  ['CENGIC, HASAN '],
#  ['CERKEZ, MARIO '],
#  ['CESIC, RANKO '],
#  ['CESIC-ROJS, LJUBO '],
#  ['CETNIK RAVNAGORSKI POKRET; CRP; '],
#  ['CORIC, VALENTIN '],
#  ['DALIPI, TAHIR '],
#  ['DELIC, HAZIM '],
#  ['DERONJIC, MIROSLAV '],
#  ['DJOGO, JOVAN '],
#  ['DOSEN, DAMIR '],
#  ['ELSHANI, GAFUR '],
#  ['FRONT FOR ALBANIAN NATIONAL UNITY; FBKSH; '],
#  ['FURUNDZIJA, ANTO '],
#  ['FUSTAR, DUSAN '],
#  ['GAJIC-MILOSEVIC, MILICA '],
#  ['GALIC, STANISLAV '],
# ...
#  ['AL-RAWI, AYAD FUTAYYIH KHALIFA '],
#  ['AL-NAQIB, ZUHAIR TALIB ABD-AL-SATTAR '],
#  ["AL-SA'DI, AMIR HAMUDI HASSAN "],
#  ['AL-UBAIDI, AMIR RASHID MUHAMMAD '],
#  ['AL-YASSIN, HUSAM MUHAMMAD AMIN '],
#  ['AL-SALIH, MUHAMMAD MAHDI; SALEH, MOHAMMED MAHDI; '],
#  ["AL-TIKRITI, SAB'AWI IBRAHIM HASSAN; AL-TAKRITI, SABAWI IBRAHIM HASSAN; "],
#  ['AL-TIKRITI, WATBAN IBRAHIM HASSAN; AL-HASSAN, WATAB IBRAHIM; AL-TAKRITI, WATBAN; AL-TIKRITI, WATBAN IBRAHIM AL-HASAN; '],
#  ['AL-TIKRITI, BARZAN IBRAHIM HASSAN; AL-TAKRITI, BARZAN IBRAHIM HASSAN; AL-TIKRITI, BARZAN IBRAHIM HASAN; '],
#  ['AMMASH, HUDA SALIH MAHDI '],
#  ["AL-SAD'UN, ABD-AL-BAQI ABD-AL-KARIM ABDALLAH "],
#  ["AL-SA'DUN, MUHAMMAD ZIMAM ABD-AL-RAZZAQ "],
#  ['AL-NAJIM, SAMIR ABD AL-AZIZ '],
#  ["ABD-AL-GHAFUR, HUMAM ABD-AL-KHALIQ; 'ABD AL-RAHMAN, HUMAM 'ABD AL-KHALIQ; RASHID, HUMAM 'ABD AL-KHALIQ; GHAFUR, HUMAM ABDEL KHALEQ ABDEL; ABD AL-GHAFUR, HUMAM ABD AL-KHALIQ; "],
#  ['AL-UBAIDI, YAHIA ABDALLAH '],
#  ['GHALIB, NAYIF SHINDAKH THAMIR '],
#  ['AL-MASHHADANI, SAIF-AL-DIN '],
#  ['GHARIB, FADIL MAHMUD; AL-MASHAIKHI, GHARIB MUHAMMAD FAZEL; '],
#  ['AL-KHAFAJI, MUHSIN KHADR '],
#  ['KAZIM, RASHID TAAN '],
#  ['AL-KUBAYSI, UGLA ABID SAQAR; SAQR AL-KABISI ABD AQALA; '],
#  ['AL-UBAIDI, GHAZI HAMMUD '],
#  ['MAHDI, ADIL ABDALLAH '],
#  ['AL-AWADI, HUSSEIN QAID '],
#  ['AL-MUHAMMAD, KHAMIS SIRHAN  DR. KHAMIS.'],
#  ["AL-TIKRITI, SA'D ABD-AL-MAJID AL-FAYSAL "],
#  ['SPASOJEVIC, DRAGON '],
#  ['VASIC, DRAGOMIR '],
#  ['ASSOCIATION DE SECOURS PALESTINIENS; ASSOCIATION FOR PALESTINIAN AID; ASSOCIATION SECOUR PALESTINIEN; HUMANITARE HILFSORGANISATION FUR PALASTINA; LAJNA AL-IGHATHA AL-FILISTINI; PALESTINE RELIEF COMMITTEE; PALESTINIAN AID COUNCIL; PALESTINIAN AID ORGANIZATION; PALESTINIAN RELIEF SOCIETY; RELIEF ASSOCIATION FOR PALESTINE;  ASP.'],
#  ["SANABIL ASSOCIATION FOR RELIEF AND DEVELOPMENT; AL SANABIL; AL-SANBAL; ASANABIL; JA'MIA SANBLE LLAGHATHA WA ALTINMIA; JAMI'A SANABIL; JAMI'A SANABIL LIL IGATHA WA AL-TANMIYZ; SANABAL; SANABEL; SANABIL AL-AQSA; SANABIL FOR AID AND DEVELOPMENT; SANABIL FOR RELIEF AND DEVELOPMENT; SANABIL GROUP FOR RELIEF AND DEVELOPMENT; SANIBAL; SANNABIL; SANNIBIL; SINABUL; "],
#  ['DWIKARNA, AGUS '],
#  ['JULKIPLI SALIM Y SALAMUDDIN; JULKIPLI, SALIM; '],
#  ['MUNANDAR, ARIS '],
#  ['MURAD, ABDUL HAKIM; AHMED, SAEED; AKMAN, SAEED; MURAD, ABDUL HAKIM AL HASHIM; MURAD, ADBUL HAKIM ALI HASHIM; MURAD, ABDUL HAKIM HASIM; '],
#  ['SIREGAR, PARLINDUNGAN; SIREGAR, PARLIN; SIREGAR, SALEH PARLINDUNGAN; '],
#  ['SYAWAL, YASSIN; MOCHTAR, YASIN MAHMUD; MUBAROK, MUHAMAD; SYAWAL, MUHAMMAD; YASIN, ABDUL HADI; YASIN, SALIM; YASIN, SYAWAL; MUBARAK, LAODE AGUSSALIM; MUHAMMAD, USTAD HAJI LAUDI AGUS SALIM; KHAN, MOHD SHAHWAL; IDA, LAODE;  ABU MUAMAR; ABU SETA; MAHMUD; AGUS SALIM.'],
#  ['YUNOS, MUKHLIS; YUNOS, MUKLIS; YUNOS, SAIFULLAH MUKHLIS; '],
#  ['BIN MANSOUR, AMRAN; BIN MANSOR, AMRAN; BIN MANSOR, HENRY; '],
#  ['HIR, ZULKIFLI BIN ABDUL; HIR, MUSA ABDUL; HIR, ZULKIFLI ABDUL; ZULKIFLI, ABDUL HIR BIN; ZULKIFLI, BIN ABDUL HIR;  MUSA ABDUL.'],
#  ['KASMURI, ABDUL MANAF; KASMURI, LT. COL. (RTD). ABD MANAF; '],
#  ['MARZUKI, ZULKIFLI; BIN MARZUKI, ZULKIFLI; BIN ZUKEPLI, MARZUKI; MARZUKI, ZULKEPLI;  ZUKIPLI; ZULKIFLI.'],
#  ['SUFAAT, YAZID; BIN SUFAAT, YAZUD; SHUFAAT, YAZID; '],
#  ['WAN MIN, WAN MAT; WAN MIN, BIN WAN MAT; '],
#  ['ZAKARIA, ZAINI '],
#  ['ABU DHESS, MOHAMED; HASSAN, YASER;  ABU ALI.'],
#  ['AL-DAGMA, ASCHRAF  NOOR.'],
#  ['MOUSTFA, DJAMEL; KALED, BELKASAM;  ALI BARKANI; MOUSTAFA.'],
#  ['SHALABI, ISMAIL ABDALLAH SBAITAN '],
#  ['AL-AKHTAR TRUST INTERNATIONAL; AKHTARABAD MEDICAL CAMP; AL-AKHTAR MEDICAL CENTRE; PAKISTAN RELIEF FOUNDATION; PAKISTANI RELIEF FOUNDATION; AZMAT-E-PAKISTAN TRUST; AZMAT PAKISTAN TRUST; '],
#  ['AL-BAKOUN ALA AL-AHD ORGANIZATION; FAITHFUL TO THE OATH; '],
#  ['BELMOKHTAR, MOKHTAR '],
#  ["DHAMAT HOUMET DAAWA SALAFIA; DJAMAAT HOUMAT ED DAWA ESSALAFIA; DJAMAAT HOUMAT ED DAAWA ES SALAFIYA; DJAMAATT HOUMAT ED DAAWA ES SALAFIYA; EL-AHOUAL BATTALION; GROUP PROTECTORS OF SALAFIST PREACHING; GROUP OF SUPPORTERS OF THE SALAFIST TREND; GROUP OF SUPPORTERS OF THE SALAFISTE TREND; THE HORROR SQUADRON; HOUMAT ED DAAWA ES SALIFIYA; HOUMAT ED-DAAOUA ES-SALAFIA; HOUMATE ED-DAAWA ES-SALAFIA; HOUMATE EL DA'AWAA ES-SALAFIYYA; KATIBAT EL AHOUAL; KATIBAT EL AHOUEL; PROTECTORS OF THE SALAFIST CALL; PROTECTORS OF THE SALAFIST PREDICATION; SALAFIST CALL PROTECTORS; "],
#  ['EL HADI, MUSTAPHA NASRI BEN ABDUL KADER AIT '],
#  ['LOUNICI, DJAMEL '],
#  ['BEN ABDELHAKIM, CHERIF SAID; ABOU SALMAN; AL-CHERIF, SAID BEN ABDELHAKIM BEN OMAR;  DJALLAL; YOUCEF.'],
#  ['BOUYAHIA, HAMADI BEN ABDUL AZIZ BEN ALI; GAMEL MOHAMED; '],
#  ['CABDULLAAH, CIISE MAXAMED '],
#  ['DRISSI, NOUREDDINE BEN ALI BEN BELKASSEM '],
#  ['EL AYASHI, RADI ABD EL SAMIE ABOU EL YAZID  MERAI.'],
#  ['HAMMID, MOHAMMED TAHIR  ABDELHAMID AL KURDI.'],
#  ['HAMRAOUI, KAMEL BEN MOULDI BEN HASSAN  KAMEL; KIMO.'],
#  ['MOSTAFA, MOHAMED AMIN '],
#  ['RIHANI, LOTFI BEN ABDUL HAMID BEN ALI  ABDERRAHMANE.'],
#  ['ROUINE, LAZHER BEN KHALIFA BEN AHMED; ROUINE, AL-AZHAR BEN KHALIFA BEN AHMED;  LAZHAR; SALMANE.'],
#  ['SALEH AL-SAADI, NASSIM BEN MOHAMED AL-CHERIF BEN MOHAMED  ABOU ANIS.'],
#  ['TRABELSI, MOURAD; ABOU DJARRAH; AL-TRABELSI, MOURAD BEN ALI BEN AL-BASHEER; '],
#  ['ZARKAOUI, IMED BEN MEKKI BEN AL-AKHDAR  NADRA; ZARGA.'],
#  ['AMMARI, SAIFI  ABDALARAK; ABDERREZAK LE PARA; ABDERREZAK ZAIMECHE; ABDUL RASAK AMMANE ABU HAIDRA; ABOU HAIDARA; EL PARA; EL OURASSI.'],
#  ['DURGUTI, SAFET  ABU-SUMAYA.'],
#  ['ABO GHAITH, SULAIMAN JASSEM '],
#  ["AL-HARAMAIN : PAKISTAN BRANCH; AL-HARAMAIN FOUNDATION; AL-HARAMAIN HUMANITARIAN FOUNDATION; AL-HARAMAIN ISLAMIC FOUNDATION; AL-HARAMAYN; AL-HARAMAYN FOUNDATION; AL-HARAMAYN HUMANITARIAN FOUNDATION; AL-HARAMAYN ISLAMIC FOUNDATION; AL-HARAMEIN; AL-HARAMEIN FOUNDATION; AL-HARAMEIN HUMANITARIAN FOUNDATION; AL-HARAMEIN ISLAMIC FOUNDATION; ALH
AL-KHAYRIYYA; MU'ASSASAT AL-HARAMAYN AL-KHAYRIYYA; MU'ASSASAT AL-HARAMEIN AL-KHAYRIYYA; VAZIR; VEZIR; "],
#  ['BASEVIC, DRAGAN '],
#  ['BOROVCANIN, VELJKO '],
#  ['DJORDA, SAMOJKO '],
#  ['ECIM, LJUBAN '],
#  ['JAKUPI, AVDYL '],
#  ['KOJIC, RADOMIR  MINEUR.'],
#  ['KOVAC, TOMISLAV  TOMO.'],
#  ['KUJUNDZIC, PREDRAG  PREDO.'],
#  ['MARIJANOVIC, MILOVAN '],
#  ['SARAC, IVAN '],
#  ['SHAQIRI, XHEZAIR '],
#  ['THACI, MENDUH '],
#  ['2904977 CANADA, INC.; CARIBE SOL; HAVANTUR CANADA INC.; '],
#  ['CORPORACION CIMEX S.A.; CIMEX; CIMEX CUBA; COMERCIO INTERIOR, MERCADO EXTERIOR; '],
#  ['CUBANACAN GROUP; CUBANACAN; EL GRUPO CUBANACAN; '],
#  ['CUBANACAN INTERNATIONAL B.V '],
#  ['CUBANACAN U.K. LIMITED '],
#  ['HAVANATUR S.A.; HAVANATUR, S.A.; '],
#  ['HAVANATUR BAHAMAS LTD. '],
#  ['HAVANATUR CHILE S.A.; GUAMATUR S.A.; '],
#  ['LA COMPANIA TIENDAS UNIVERSO S.A.; WWW.CUBA-SHOP.NET; '],
#  ['FUNDACION PARA LA PAZ DE CORDOBA; FUNDACION POR LA PAS DE CORDOBA; FUNDAZCOR; FUNPAZCOR; '],
#  ['ALBAN BURBANO, LUIS ALBERTO; ALBAN URBANO, LUIS ALBERTO; CALARCA, MARCO LEON; CALARCA, MARCOS LEON; '],
#  ['ARROYAVE RUIZ, ELKIN ALBERTO; LOPEZ, CESAR; '],
#  ['ATENCIA PITALUA, RAFAEL DARIO '],
#  ['BLANCO PUERTA, EDGAR FERNANDO '],
#  ['BOCOTA AGUABLANCA, GUSTAVO; BOGOTA, GUSTAVO;  ESTEVAN; TRIBISU.'],
#  ['BRICENO SUAREZ, GERMAN; SUAREZ ROJAS, NOE;  GRANOBLES.'],
#  ['SUAREZ ROJAS, VICTOR JULIO  MONO JOJOY; OSCAR RIANO; SUAREZ, LUIS.'],
#  ['BUITRAGO PARADA, HECTOR GERMAN  MARTIN LLANOS.'],
#  ['CABRERA, JOSE BENITO; CABRERA CUEVAS, JOSE BENITO;  FABIAN RAMIREZ; EL MONO FABIAN.'],
#  ['CARACAS VIVEROS, OSCAR  EL NEGRO OSCAR.'],
#  ['CASTANO GIL, CARLOS '],
#  ['CASTANO GIL, JOSE VICENTE '],
#  ['CASTELLANOS GARZON, HENRY  COMANDANTE ROMANA; EDISON ROMANA; ROMANA.'],
#  ['CIFUENTES GALINDO, LUIS EDUARDO  EL AGUILA.'],
#  ['DEVIA SILVA, LUIS EDGAR  RAUL REYES.'],
#  ['DUQUE GAVIRIA, IVAN ROBERTO  ERNESTO BAEZ.'],
#  ['GIRALDO SERNA, HERNAN '],
#  ['GOMEZ ALVAREZ, SOR TERESA  LA NEGRA'],
#  ['ISAZA ARANGO, RAMON MARIA '],
#  ['LONDONO ECHEVERRY, RODRIGO  TIMOLEON JIMENEZ; TIMOCHENKO.'],
#  ['MANCUSO GOMEZ, SALVATORE; LOZADA, SANTANDER; '],
#  ['MARIN ARANGO, LUCIANO  IVAN MARQUES; IVAN  MARQUEZ.'],
#  ['MARIN, PEDRO ANTONIO; MARIN MARIN, PEDRO ANTONIO;  MANUEL MARULANDA; MANUEL MARULANDA VELEZ; TIROFIJO.'],
#  ['MATA MATA, NOEL; MATTA MATTA, NOEL;  EFRAIN GUZMAN; EL CHUCHO.'],
#  ['MOLINA CARACAS, TOMAS; CASTILLO CORTES, MIGUEL ANGEL; MEDINA CARACAS, TOMAS;  ARTURO GUEVARA; EL PATRON; JORGE MEDINA; NEGRO ACACIO.'],
#  ['MURILLO BEJARANO, DIEGO FERNANDO  ADOLFO PAZ; DON BERNA.'],
#  ['PINEDA PALMERA, JUVENAL OVIDIO; PALMERA PINEDA, JUVENAL OVIDIO RICARDO;  SIMON TRINIDAD.'],
#  ['SAENZ VARGAS, GUILLERMO LEON  ALFONSO CANO.'],
#  ['TONCEL REDONDO, MILTON DE JESUS  EL NEGRO; JOAQUIN GOMEZ; ORO CHURCO; USURRIAGA.'],
#  ['TORRES VICTORIA, JORGE  PABLO CATATUMBO.'],
#  ['VARGAS PERDOMO, EUGENIO; DORNELES DE MENEZES, FRANCISCO;  CARLOS BOLAS.'],
#  ["AL-ZINDANI, SHAYKH ABD-AL-MAJID; AL-ZINDANI, ABDELMAJID; AL-ZINDANI, SHAYKH 'ABD AL-MAJID; "],
#  ['LITTLE CONNEMARA 1 FARM '],
#  ['LOT 3A OF DETE VALLEY FARM '],
#  ['M & S SYNDICATE (PVT) LTD.; M AND S SYNDICATE (PVT) LTD.; '],
#  ['PATTERSON FARM '],
#  ['ZIMBABWE DEFENCE INDUSTRIES (PVT) LTD. '],
#  ['ABD AL-GHAFAR, SUNDUS '],
#  ['AL-DURI, JAWHAR MAJID '],
#  ["AL-RABI'I, NIDAL "],
#  ['AL-TIKRITI, ALI BARZAN IBRAHIM HASAN '],
#  ['AL-TIKRITI, ALI SADDAM HUSSEIN  HASSAN.'],
#  ['AL-TIKRITI, HALA SADDAM HUSSEIN '],
#  ['AL-TIKRITI, KHAWLA BARZAN IBRAHIM HASAN '],
#  ['AL-TIKRITI, MOHAMMAD BARZAN IBRAHIM HASAN '],
#  ['AL-TIKRITI, NOOR BARZAN IBRAHIM HASAN '],
#  ['AL-TIKRITI, RAGHAD SADDAM HUSSEIN '],
#  ['AL-TIKRITI, RANA SADDAM HUSSEIN '],
#  ['AL-TIKRITI, SAJA BARZAN IBRAHIM HASAN '],
#  ['AL-TIKRITI, THORAYA BARZAN IBRAHIM HASAN '],
#  ['AL-UBAYDI, INTISSAR '],
#  ['SHAHBANDAR, SAMIRA  CHADIAN.'],
#  ['TILFAH, SAJIDA KHAYRALLAH '],
#  ['HOLA SUN HOLIDAYS LIMITED '],
#  ['DERAMCHI, OTHMAN  YOUSSEF, ABOU.'],
#  ["BENDEBKA, L'HADI  ABD AL HADI; HADI."],
#  ['AHMED NACER, YACINE; YACINE DI ANNABA; '],
#  ['KIFANE, ABDERRAHMANE '],
#  ['EL HEIT, ALI; KAMEL, MOHAMED;  ALI DI ROMA.'],
#  ['HADDAD, FETHI BEN ASSEN BEN SALEM '],
#  ['ABBES, MOUSTAFA '],
#  ['ABBES, YOUCEF  GIUSEPPE.'],
#  ['AL WASEL AND BABEL GENERAL TRADING LLC '],
#  ["AL-BASHAIR TRADING COMPANY, LTD; AL-BASHAAIR TRADING COMPANY, LTD; AL-BASHAER TRADING COMPANY, LTD; AL-BASHA'IR TRADING COMPANY, LTD; AL-BASHIR TRADING COMPANY, LTD; "],
#  ['AL-HUDA STATE COMPANY FOR RELIGIOUS TOURISM; AL-HODA FOR RELIGIOUS TOURISM COMPANY; AL-HODA STATE COMPANY FOR RELIGIOUS TOURISM; AL-HUDA FOR RELIGIOUS TOURISM COMPANY; '],
#  ['AVIATRANS ANSTALT; AVIATRANS ESTABLISHMENT; '],
#  ['LOGARCHEO S.A.; LOGARCHEO AG; '],
#  ['AHMED, ADNAN S. HASAN; ADNAN, AHMED S. HASAN; SULTAN, AHMED; '],
#  ["AL OBAIDI, TARIK NASSER S.; AL-'UBAYDI, TARIK; AL-'UBAYDI, TARIQ; "],
#  ['AL-QUBAYSI, MUNIR; AL-KUBAISI, MUNEER; AL-KUBAYSI, MUNIR; AWAD, MUNIR A.; AWAD, MUNIR MAMDUH; '],
#  ['BAHNAM, HIKMAT JARJES; GARGEES, HIKMAT; '],
#  ['ALLANE, HACENE; ABDELHAY, AL-SHEIKH; AHCENE, CHEIB;  ABU AL-FOUTOUH; BOULAHIA; HASSAN THE OLD.'],
#  ['DJERMANE, KAMEL  ADEL; BILAL; FODHIL.'],
#  ['EL-AICH, DHOU  ABDEL HAK.'],
#  ['ZERFAOUI, AHMAD  ABDALLA; ABDULLAH; ABU CHOLDER; ABU KHAOULA; NUHR; SMAIL.'],
#  ['AL-HARAMAIN & AL MASJED AL-AQSA CHARITY FOUNDATION : BOSNIA BRANCH; AL HARAMAIN AL MASJED AL AQSA; AL HARAMAYN AL MASJID AL AQSA; AL-HARAMAYN AND AL MASJID AL AQSA CHARITABLE FOUNDATION; '],
#  ['TAIBAH INTERNATIONAL : BOSNIA BRANCH; TAIBAH INTERNATIONAL AID AGENCY; TAIBAH INTERNATIONAL AID ASSOCIATION; AL TAIBAH, INTL.; TAIBAH INTERNATIONAL AIDE ASSOCIATION; '],
#  ["AL FURQAN; DZEMILIJATI FURKAN; DZEM'IJJETUL FURQAN; ASSOCIATION FOR CITIZENS RIGHTS AND RESISTANCE TO LIES; DZEMIJETUL FURKAN; ASSOCIATION OF CITIZENS FOR THE SUPPORT OF TRUTH AND SUPPRESSION OF LIES; SIRAT; ASSOCIATION FOR EDUCATION, CULTURE AND BUILDING SOCIETY - SIRAT; ASSOCIATION FOR EDUCATION, CULTURAL, AND TO CREATE SOCIETY - SIRAT; ISTIKAMET; IN SIRATEL; "],
#  ['BURHAN, DR. SAHIR; AL-DEEN, SAHER BURHAN; BARHAN, DR. SAHIR; BERHAN, DR. SAHIR; BURHAN, SAHIR; '],
#  ['HAMUDAT, GENERAL MAKI MUSTAFA; AL-HAMADAT, GENERAL MAKI; HAMUDAT, MAKI; HMODAT, MACKIE; MUSTAFA, MACKI HAMOUDAT; '],
#  ['SHABAN, ADIB; AL-ANI, ADIB SHABAN; SHABAN, DR. ADIB; '],
#  ['SLEWA, ROODI; SALIWA, RUDI; SLAIWAH, RUDI; SLAY WAH, RUDI UNTAYWAN; '],
#  ...]

# %% [markdown]
# However, when converting our dataframe, we find that it becomes a list of lists; and we are now required to convert the list of lists into a single, flat list

# %%
sdnflat=[]
for i in sdnlist:
  for j in i:
    sdnflat.append(j)
print (sdnflat)
# Out:
# ['AEROCARIBBEAN AIRLINES; AERO-CARIBBEAN; ', 'ANGLO-CARIBBEAN CO., LTD.; AVIA IMPORT; ', 'BANCO NACIONAL DE CUBA; NATIONAL BANK OF CUBA;  BNC.', 'BOUTIQUE LA MAISON ', 'CASA DE CUBA ', 'CECOEX, S.A. ', 'CIMEX ', 'CIMEX IBERICA ', 'CIMEX, S.A. ', 'COMERCIAL IBEROAMERICANA, S.A.; COIBA; ', 'COMERCIAL CIMEX, S.A. ', 'COMERCIAL DE RODAJES Y MAQUINARIA, S.A.; CRYMSA; ', 'COMERCIALIZACION DE PRODUCTOS VARIOS; COPROVA; COPROVA SARL; ', 'COMPANIA DE IMPORTACION Y EXPORTACION IBERIA; CIMEX; ', 'CORPORACION CIMEX, S.A. ', 'COTEI ', 'CRUZ, JUAN M. DE LA ', 'CRYMSA - ARGENTINA, S.A. ', 'CUBACANCUN CIGARS AND GIFT SHOPS ', 'CUBAEXPORT ', 'CUBAFRUTAS ', 'CUBAN CIGARS TRADE ', 'CUBANATUR ', 'CUBATABACO ', 'CUMEXINT, S.A. ', 'DELVEST HOLDING, S.A.; DELVEST HOLDING COMPANY; ', 'EDICIONES CUBANAS ', 'EDYJU, S.A. ', 'EMPRESA CUBANA DE AVIACION; CUBANA AIRLINES; ', 'EMPRESA CUBANA DE PESCADOS Y MARISCOS; CARIBBEAN EXPORT ENTERPRISE;  CARIBEX.', 'EMPRESA DE TURISMO NACIONAL Y INTERNACIONAL; CUBATUR; ', 'ETCO INTERNATIONAL COMMODITIES LTD. ', 'ETCO INTERNATIONAL COMPANY, LIMITED ', 'GALAX TRADING CO., LTD.; GALAX INC.; ', 'GUTIERREZ REYES, JOSE ', 'HAVIN BANK LIMITED; HAVANA INTERNATIONAL BANK, LTD; ', 'HAVANATUR ', 'INSTITUTO NACIONAL DE TURISMO DE CUBA ', 'INTERCONSULT ', 'KAVE, S.A. ', 'LA EMPRESA CUBANA DE FLETES; CUFLET; CUBAN FREIGHT ENTERPRISE; ', 'LEVERAGE, S.A. ', 'NIREF ', 'NORDSTRAND LTD. ', 'NORDSTRAND MARITIME AND TRADING COMPANY ', 'NORIEGA, MANUEL ANTONIO ', 'PANAMERICAN IMPORT AND EXPORT COMMERCIAL CORPORAT
IA ', 'CONCRETOS CALI S.A. ', 'CONSTRUCTORA DIMISA LTDA. ', 'ABRIL CORTEZ, OLIVERIO; CORTEZ, OLIVERIO ABRIL; ABRIL CORTES, OLIVERIO; ', 'CUARTES MORALES, JUAN CARLOS ', 'ESCOBAR BUITRAGO, WALTER ', 'GALINDO, GILMER ANTONIO; GUZMAN TRUJILLO, CARLOS ARTURO; ', 'GALINDO HERRERA, DIANA PAOLA ', 'GALINDO HERRERA, DIEGO ALEXANDER ', 'GIRALDO SARRIA, OCTAVIO ', 'GOMEZ BERRIO, OLMES DE JESUS; GOMEZ BERRIO, HOLMES DE JESUS; ', 'HERNANDEZ CANOBAS, HECTOR FABIO ', 'HERRERA BUITRAGO, ALVARO ', 'HERRERA BUITRAGO, STELLA ', 'IBANEZ LOPEZ, RAUL ALBE ...

# %% [markdown]
# We define a function, using FuzzyWuzzy, which aims to return us two values - the closest hit, and the fuzzymatch score. We also define a condition so that we are only informed of potential matches scoring over 85 - our minimum threshold.
#
# We aim to run this algorithm across the four various fuzzy match types FuzzyWuzzy offers us:
#
# - Simple Ratio | Comparing the similairity between two strings
# - Partial Ratio | Comparing the similarity between two strings whilst also taking partial/substrings into consideration
# - Token Sort Ratio | Comparing the similarity between two strings, partially disregarding the order of characters within the string
# - Token Set Ratio | Comparing the similarity between two stings in a way similar to Token Sort; however, instead of being strings being sorted alphabetically and compared, the tokens are split into two groups: the ‘intersection’ and the ‘remainder’, and are then compared

# %%
def fuzz_m(col, sdn, score_t):
    potential_hit, score = process.extractOne(col, sdn, scorer=score_t)
    if score<85:
        return "", ""
    else:
        return potential_hit, score

clients['Ratio Match'],clients['Ratio Score'] = zip(*clients['Client Name'].apply(fuzz_m, sdn=sdnflat, score_t=fuzz.ratio))
clients['Partial Ratio Match'], clients['Partial Score'] = zip(*clients['Client Name'].apply(fuzz_m, sdn=sdnflat, score_t=fuzz.partial_ratio))
clients['Token Sort Match'], clients['Token Sort Score'] = zip(*clients['Client Name'].apply(fuzz_m, sdn=sdnflat, score_t=fuzz.token_sort_ratio))
clients['Token Set Match'], clients['Token Set Score'] = zip(*clients['Client Name'].apply(fuzz_m, sdn=sdnflat, score_t=fuzz.token_set_ratio))

# %% [markdown]
# Our output should display the input data (Customer Name) in the leftmost column, and then the best match (taking the specified threshold of fuzzymatch score of 85 and above into consideration) and its respective fuzzymatch score for each fuzzymatch type in the subsequent columns

# %%
display(clients)
# Out:
#                Client Name Ratio Match Ratio Score Partial Ratio Match  \
# 0               JOHN BROWN
# 1              MIKA ARSHAD                                    PARSHAD
# 2     ENRIQUE TORRES GOMEZ
# 3                HUD SALEM
# 4             AMBER DAVIES
# ...                    ...         ...         ...                 ...
# 5768          GAYNOR SMITH
# 5769      PEPILLO THOMPSON
# 5770          JARIYAH LONE
# 5771        WASFIYAH MAHDI
# 5772          EVONNE JONES
#
#      Partial Score Token Sort Match Token Sort Score Token Set Match  \
# 0
# 1               86
# 2
# 3
# 4
# ...            ...              ...              ...             ...
# 5768
# 5769
# 5770
# 5771
# 5772
#
#      Token Set Score
# 0
# 1
# 2
# 3
# 4
# ...              ...
# 5768
# 5769
# 5770
# 5771
# 5772
#
# [5773 rows x 9 columns]

# %% [markdown]
# We can then use the export function to save our new dataframe, which includes the results of our FuzzyWuzzy matches, to a .csv file for our reference

# %%
clients.to_csv('C:\\Users\\ronel\\OneDrive\\Documents\\Python\Fuzzy Logic 85.csv')

# %% [markdown]
# We run the model again, but this time our similarity score threshold is set to 90 in order to limit the scope for false positives (although we can also just disregard all scores below 90 from our previous results to acheive the same).

# %%
def fuzz_m(col, sdn, score_t):
    potential_hit, score = process.extractOne(col, sdn, scorer=score_t)
    if score<90:
        return "", ""
    else:
        return potential_hit, score

clients['Ratio Match'],clients['Ratio Score'] = zip(*clients['Client Name'].apply(fuzz_m, sdn=sdnflat, score_t=fuzz.ratio))
clients['Partial Ratio Match'], clients['Partial Score'] = zip(*clients['Client Name'].apply(fuzz_m, sdn=sdnflat, score_t=fuzz.partial_ratio))
clients['Token Sort Match'], clients['Token Sort Score'] = zip(*clients['Client Name'].apply(fuzz_m, sdn=sdnflat, score_t=fuzz.token_sort_ratio))
clients['Token Set Match'], clients['Token Set Score'] = zip(*clients['Client Name'].apply(fuzz_m, sdn=sdnflat, score_t=fuzz.token_set_ratio))

# %%
display(clients)
# Out:
#                Client Name Ratio Match Ratio Score Partial Ratio Match  \
# 0               JOHN BROWN
# 1              MIKA ARSHAD
# 2     ENRIQUE TORRES GOMEZ
# 3                HUD SALEM
# 4             AMBER DAVIES
# ...                    ...         ...         ...                 ...
# 5768          GAYNOR SMITH
# 5769      PEPILLO THOMPSON
# 5770          JARIYAH LONE
# 5771        WASFIYAH MAHDI
# 5772          EVONNE JONES
#
#      Partial Score Token Sort Match Token Sort Score Token Set Match  \
# 0
# 1
# 2
# 3
# 4
# ...            ...              ...              ...             ...
# 5768
# 5769
# 5770
# 5771
# 5772
#
#      Token Set Score
# 0
# 1
# 2
# 3
# 4
# ...              ...
# 5768
# 5769
# 5770
# 5771
# 5772
#
# [5773 rows x 9 columns]

# %%
clients.to_csv('C:\\Users\\ronel\\OneDrive\\Documents\\Python\Fuzzy Logic 90.csv')

# %% [markdown]
# #### Limitations of FuzzyWuzzy
#
# A significant limitation of the FuzzyWuzzy package is that it doesn’t account for phonetic similarities – something which undoubtedly assist in identifying individuals whose names have been transliterated from non-Latin scripts such as Arabic and Chinese
#
# One particular example of could be the name ‘عُثْمان’; which can be transliterated to Othman, Uthman, Osman or Usmaan amongst a few other options. If coupled with another name ‘مايكل’; which could be transliterated to Mika’eel just as easily as it could be Mikhail, we could find ourselves with false negatives when trying to match transliterated combinations against one another
#
# Despite being the same name, FuzzyWuzzy fails to identify a potential match for a score benchmark of below 65

# %%
A = fuzz.ratio("OTHMAN MIKHAIL","USMAAN MIKA'EEL")
B = fuzz.partial_ratio("OTHMAN MIKHAIL","USMAAN MIKA'EEL")
C = fuzz.token_sort_ratio("OTHMAN MIKHAIL","USMAAN MIKA'EEL")
D = fuzz.token_set_ratio("OTHMAN MIKHAIL","USMAAN MIKA'EEL")

print(A,B,C,D)
# Out:
# 62 64 55 55

# %%
AA = fuzz.ratio("OTHMAN MICHAEL", "USMAAN MIKA'EEL")
BB = fuzz.partial_ratio("OTHMAN MICHAEL","USMAAN MIKA'EEL")
CC = fuzz.token_sort_ratio("OTHMAN MICHAEL","USMAAN MIKA'EEL")
DD = fuzz.token_set_ratio("OTHMAN MICHAEL","USMAAN MIKA'EEL")

print(AA,BB,CC,DD)
# Out:
# 62 64 48 48

# %% [markdown]
# __With all screening models, it is important to understand given the importance of financial crime prevention, that a decrease in false positives should not come at an expense of an increase in false negatives.__
